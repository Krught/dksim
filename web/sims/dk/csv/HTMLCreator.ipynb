# %%
import pandas as pd
enchants_weapon = ["Rune of Cinderglacier", "Rune of Lichbane", "Rune of Razorice", "Rune of the Fallen Crusader", "Enchant Weapon - Exceptional Agility", "Enchant Weapon - Berserking", "Enchant Weapon - Superior Potency", "Enchant Weapon - Greater Potency", "Enchant Weapon - Accuracy", "Titanium Weapon Chain", "Enchant Weapon - Greater Savagery", "Enchant Weapon - Massacre", "Consecrated Sharpening Stone"]
enchants_head = ["Arcanum of Torment", "Arcanum of Triumph"]
enchants_shoulders = ["Lesser Inscription of the Axe", "Greater Inscription of the Axe", "Master's Inscription of the Axe", "Inscription of Triumph"]
enchants_back = ["Enchant Cloak - Greater Speed", "Enchant Cloak - Major Agility", "Enchant Cloak - Speed", "Enchant Cloak - Superior Agility", "Swordguard Embroidery", "Flexweave Underlay"]
enchants_chest = ["Enchant Chest - Powerful Stats", "Enchant Chest - Super Stats"]
enchants_wrist = ["Enchant Bracers - Expertise", "Enchant Bracers - Greater Assault", "Enchant Bracers - Greater Stats", "Enchant Bracers - Striking", "Fur Lining - Attack Power"]
enchants_gloves = ["Enchant Gloves - Crusher", "Enchant Gloves - Expertise", "Enchant Gloves - Greater Assault", "Enchant Gloves - Major Agility", "Enchant Gloves - Precision", "Hyperspeed Accelerators"]
enchants_leg = ["Frosthide Leg Armor", "Icescale Leg Armor", "Jormungar Leg Armor", "Nerubian Leg Armor", "Jormungar Leg Reinforcements", "Nerubian Leg Reinforcements"]
enchants_boots = ["Enchant Boots - Assault", "Enchant Boots - Greater Assault", "Enchant Boots - Icewalker", "Enchant Boots - Superior Agility", "Nitro Boosts"]
enchants_rings = ["Enchant Ring - Assault", "Enchant Ring - Stats", "Enchant Ring - Greater Spellpower"]
exported_cookie_list = ['w1_selector()', 'w2_selector()', 'hd_selector()', 'nk_selector()', 'ss_selector()', 'bk_selector()', 'ct_selector()', 'wr_selector()', 'gs_selector()', 'wt_selector()', 'ls_selector()', 'bs_selector()', 'r1_selector()', 'r2_selector()', 't1_selector()', 't2_selector()', 'sl_selector()', 'gn1_selector()', 'gn2_selector()', 'gn3_selector()', 'gn4_selector()', 'gn5_selector()', 'gn6_selector()', 'gn7_selector()', 'gn8_selector()', 'gn9_selector()', 'g10_selector()', 'g11_selector()', 'g12_selector()', 'g13_selector()', 'g14_selector()', 'g15_selector()', 'g16_selector()', 'g17_selector()', 'g18_selector()', 'g19_selector()', 'g20_selector()', 'g21_selector()', 'g22_selector()', 'g23_selector()', 'g24_selector()', 'g25_selector()', 'g26_selector()', 'g27_selector()', 'g28_selector()', 'g29_selector()', 'g30_selector()', 'g31_selector()', 'g32_selector()', 'g33_selector()', 'g34_selector()', 'g35_selector()', 'g36_selector()', 'g37_selector()', 'g38_selector()', 'g39_selector()', 'g40_selector()', 'g41_selector()', 'g42_selector()', 'g43_selector()', 'g44_selector()', 'g45_selector()', 'g46_selector()', 'g47_selector()', 'g48_selector()', 'g49_selector()', 'g50_selector()', 'g51_selector()', 'g52_selector()', 'g53_selector()', 'g54_selector()', 'g55_selector()', 'g56_selector()', 'g57_selector()', 'g58_selector()', 'g59_selector()', 'g60_selector()', 'g61_selector()', 'g62_selector()', 'g63_selector()', 'g64_selector()', 'meta_selector()', 'mhweat_selector()', 'ohweat_selector()', 'headet_selector()', 'shoult_selector()', 'backet_selector()', 'chestt_selector()', 'wristt_selector()', 'glovet_selector()', 'legset_selector()', 'bootst_selector()', 'ring1t_selector()', 'ring2t_selector()', 'ss1_selector()', 'ss2_selector()', 'ss3_selector()', 'ss4_selector()', 'ss5_selector()', 'ss6_selector()', 'ss7_selector()', 'ss8_selector()', 'ss9_selector()', 's10_selector()', 's11_selector()', 's12_selector()', 's13_selector()', 's14_selector()', 's15_selector()', 's16_selector()']
enchants_weapon = sorted(enchants_weapon)
enchants_head = sorted(enchants_head)
enchants_shoulders = sorted(enchants_shoulders)
enchants_back = sorted(enchants_back)
enchants_chest = sorted(enchants_chest)
enchants_wrist = sorted(enchants_wrist)
enchants_gloves = sorted(enchants_gloves)
enchants_leg = sorted(enchants_leg)
enchants_boots = sorted(enchants_boots)
enchants_rings = sorted(enchants_rings)
cookie_num = 0 
cookie_gear_loop = 2
cookie_enchant_loop = 82
cookie_gem_loop = 17
cookie_metagem_loop = 81 
cookie_socket_loop = 94
sigil_loop = 16 

script_maker_names = []
script_maker_underscored_names = []
script_maker_function_names = []

# cookie_num += 1
#print('''onchange="''' + str(exported_cookie_list[0]) + '''"''')


enchant_types = ["Head","Shoulders","Back","Chest","Wrist","Gloves","Legs","Boots", "End of the Line"]
gems_data =  pd.read_csv (r'EquipmentList - Gems-dkbuilder.csv')
gem_data_entrys = len(gems_data)
gemnumber = 1
gem_counter = 0
gem_bonus_number = 1
gem_names = []
meta_gem_names = []
meta_gem_counter = 0
while gem_counter < gem_data_entrys:
    gem_names.append(gems_data['Name'].iloc[gem_counter])
    gem_counter += 1
while meta_gem_counter < 23:
    meta_gem_names.append(gems_data['Meta Name'].iloc[meta_gem_counter])
    meta_gem_counter += 1
this_gem_number = 0
def meta_gem (selection_slot):    
    #Meta Gem Selection
    if selection_slot == "Head":
        print('''<div style="text-align:center;float:center;font-size:21px;">''')
        print("<form>")
        print("Meta Gems:")
        print('''<select name="metagemselection" id="metagemselection"''' + '''onchange="''' + str(exported_cookie_list[cookie_metagem_loop]) + '''"''' + '''>''')
        print('''<option value="None"selected="selected">None</option>''')
        for gem_n in meta_gem_names:
            print('''<option value="''' + str(gem_n) + '''">'''+ str(gem_n) + '''</option>''')
        print("</select>")
        print("</form>")
        print("</div>")
    
def gem_socket_bonus(gem_bonus_number, selection_slots, cookie_socket_loop):
    if selection_slots != "Sigil":
        print('''<div style="text-align:center;float:center;font-size:21px;">''')
        print("<form>")
        print("Socket Bonus:")
        print('''<input type="checkbox" id="socketbonus''' + str(gem_bonus_number) + '''" name="socketbonus''' + str(gem_bonus_number) + '''"value="socketbonus''' + str(gem_bonus_number) + '''"''' + '''onchange="''' + str(exported_cookie_list[cookie_socket_loop]) + '''"''' + '''>''')
        cookie_socket_loop += 1
        print("</div>")
        print("</form>")
        gem_bonus_number += 1
        return gem_bonus_number, cookie_socket_loop

def all_gem(gemnumber, selection_slots, cookie_gem_loop):
    rep_number = 4
    if selection_slots == "Sigil":
        rep_number = 0
    this_gem_number = 0
    #Regular Gems Selection
    while this_gem_number < rep_number:
        print('''<div style="text-align:center;float:center;font-size:21px;">''')
        print("<form>")
        print("Gems:")
        print('''<select name="gemselection''' + str(gemnumber) + '''" id="gemselection''' + str(gemnumber) + '''"''' + '''onchange="''' + str(exported_cookie_list[cookie_gem_loop]) + '''"''' + '''>''')
        cookie_gem_loop += 1
        print('''<option value="None"selected="selected">None</option>''')
        for gem_n in gem_names:
            print('''<option value="''' + str(gem_n) + '''">'''+ str(gem_n) + '''</option>''')
        print("</select>")
        print("</form>")
        print("</div>")
        gemnumber += 1
        this_gem_number += 1
    return gemnumber, cookie_gem_loop



equipment_data = pd.read_csv (r'EquipmentList - Weapons.csv')
data_entrys = len(equipment_data)
#WEAPONS HERE
h2_selected_items = []
h1_selected_items = []
mh_selected_items = []
oh_selected_items = []
x = 0
while x < data_entrys:
    if (equipment_data['Slots'].iloc[x]) == "2handed":
        h2_selected_items.append(equipment_data['Name'].iloc[x])
    x += 1
x = 0
while x < data_entrys:
    if (equipment_data['Slots'].iloc[x]) == "1handed":
        h1_selected_items.append(equipment_data['Name'].iloc[x])
    x += 1
x = 0
while x < data_entrys:
    if (equipment_data['Slots'].iloc[x]) == "mainhand":
        mh_selected_items.append(equipment_data['Name'].iloc[x])
    x += 1
x = 0
while x < data_entrys:
    if (equipment_data['Slots'].iloc[x]) == "offhand":
        oh_selected_items.append(equipment_data['Name'].iloc[x])
    x += 1
oh_selection = h1_selected_items + oh_selected_items
oh_selection = sorted(oh_selection)
mh_selection = h2_selected_items + h1_selected_items + mh_selected_items
mh_selection = sorted(mh_selection)

print('''<div id="weapon_slot" class="tabcontent">''')
print('''<div class="weapon_tab">''')
print('''<button class="tablinks_weapon" onclick="openWeapon(event, 'weapon1_slot')"id="defaultOpen3">Main Hand</button>''')
print('''<button class="tablinks_weapon" onclick="openWeapon(event, 'weapon2_slot')">Off Hand</button>''')
print('''</div>''')

z = 0
while z < 1:
    selection_types = ["Weapon"]
    selection_slot = selection_types[0]
    selected_items = mh_selection
    selected_items_code = []
    for wep in mh_selection:
        zed = 0
        while zed < data_entrys:
            if (equipment_data['Name'].iloc[zed]) == wep:
                selected_items_code.append(equipment_data['Item Number'].iloc[zed])
            zed += 1
    for count, ele in enumerate(selected_items):
        eles = ele.find(",")
        if eles > 0:
            eles = selected_items[count]
            eles = eles.replace(",", "")
            selected_items.pop(count)
            selected_items.insert(count, eles)
    print('''<div id="''' + str(selection_slot).lower() + str(z+1) + '''_slot" class="weapon_tabcontent">''')
    print('''<div class="mhhider" id = "mhhider">
    <select name="mhhiderselection" id="mhhiderselection"onchange="mh_hider()">
    <option value="All"selected="selected">All</option>
    <option value="Sword">Sword</option>
    <option value="Axe">Axe</option>
    <option value="Mace">Mace</option>
    <option value="Polearm">Polearm</option>
    </select>
    <select name="mh2hselection" id="mh2hselection"onchange="mh_2h()">
    <option value="All"selected="selected">All</option>
    <option value="2hand">2-Hand</option>
    <option value="1hand">1-Hand</option>
    </select>
    </div>''')
    print("<form>")
    #print('''<div style="text-align:right;float:left;width:30%;font-size:21px;">''')
    print('''<div id="wepmh"class="weaponmh_selector">''')
    t = 0
    print('''<div>
    <h3>
    <div onclick="sortbyname()"class="title_name">Name <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbydps()"class="title_num">DPS <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyphase()"class="title_phase">Phase <i class="fa fa-sort"style="font-size:15px"></i></div> 
    <div onclick="sortbyheroic()"class="title_heroic">Heroic <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyslot()"class="title_slot">Slot <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbytype()"class="title_type">Type <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbymin()"class="title_min">Min <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbymax()"class="title_max">Max <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyspeed()"class="title_speed">Speed <i class="fa fa-sort"style="font-size:15px"></i></div>
    </h3>
</div>
<br>
<hr width="90%" size="2px" color="grey" align="right"/>''')
    print('''<div class="all_sort_mh">''')
    while t < len(selected_items):
        selected_items_underscore_and_no_apo = selected_items[t]
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(" ", "_")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace("'", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(":", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(",", "")
        selected_items_df = (((equipment_data[equipment_data['Name'] == selected_items[t]])))
        selected_items_phase = (selected_items_df["Phase"]).to_string(index=False, header=False)
        selected_items_heroic = (selected_items_df["Heroic"]).to_string(index=False, header=False)
        if selected_items_heroic == "False":
            selected_items_heroic = "No"
        else:
            selected_items_heroic = "Yes"
        selected_items_slot = (selected_items_df["Slots"]).to_string(index=False, header=False)
        selected_items_slot = selected_items_slot.title()
        selected_items_type = (selected_items_df["Type"]).to_string(index=False, header=False)
        selected_items_type = selected_items_type.title()
        #selected_items_type = selected_items_type.capitalize()
        selected_items_min = (selected_items_df["Min Damage"]).to_string(index=False, header=False)
        selected_items_max = (selected_items_df["Max Damage"]).to_string(index=False, header=False)
        selected_items_speed = (selected_items_df["Speed"]).to_string(index=False, header=False)
        script_maker_names.append(selected_items[t])
        script_maker_underscored_names.append("w1_" + str(selected_items_underscore_and_no_apo))
        script_maker_function_names.append("mh")
        #<div id="w1_Angry_Dread"class="w1_Angry_Dread">
        print('''<div class="all_mh_items">''')
        print('''<div id="w1_''' + str(selected_items_underscore_and_no_apo) + '''"class="w1_''' + str(selected_items_underscore_and_no_apo) + '''">''')
        print('''<a href="javascript:void(0);" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"class="name"></a>''')
        print('''<div class="nam"hidden>''' + str(selected_items[t]) + '''</div>''')
        print('''<div class="num"></div>''')
        print('''<div class="phase">''' + str(selected_items_phase) + '''</div>''')
        print('''<div class="heroic">''' + str(selected_items_heroic) + '''</div>''')
        print('''<div class="slot">''' + str(selected_items_slot) + '''</div>''')
        print('''<div class="type">''' + str(selected_items_type) + '''</div>''')
        print('''<div class="min">''' + str(selected_items_min) + '''</div>''')
        print('''<div class="max">''' + str(selected_items_max) + '''</div>''')
        print('''<div class="speed">''' + str(selected_items_speed) + '''</div>''')
        t += 1
        print("<br>")
        print("</div>")
        print('''<hr width="90%" size="2px" color="grey" align="right"/>''')
        print("</div>")

        
    print('''</div>''')
    print('''</div>''')
    print('''<select name="''' + str(selection_slot).lower() + str(z+1) + '''" id="''' + str(selection_slot).lower() + str(z+1) + '''"onchange="''' + str(exported_cookie_list[0]) + '''"hidden>''')
    y = 0
    while y < len(selected_items):
        if y == 0:
            print('''    <option value="''' + str(selected_items[y]) + '''"selected="selected">''' + str(selected_items[y]) + '''</option>''')
        else:
            print('''    <option value="''' + str(selected_items[y]) + '''">''' + str(selected_items[y]) + '''</option>''')
        y += 1
    print("</select>")
    #print("</h3>")
    print("</form>")
    
    print("""<div style="text-align:center;float:center;font-size:21px;">""")
    print("<form>")
    print("Enchant:")
    print("""<select name="mhweapenchant" id="mhweapenchant" """ + '''onchange="''' + str(exported_cookie_list[cookie_enchant_loop]) + '''"''' + """>""")
    cookie_enchant_loop += 1
    print("""<option value="None"selected="selected">None</option>""")
    for enchant in enchants_weapon:
        print('''<option value="''' + str(enchant) + '''">''' + str(enchant) + '''</option>''')
    print("</select>")
    print("</form>")
    print("</div>")
    
    gem_bonus_number, cookie_socket_loop = gem_socket_bonus(gem_bonus_number, selection_slot, cookie_socket_loop)
    gemnumber, cookie_gem_loop = all_gem(gemnumber, selection_slot, cookie_gem_loop)
    
    print('</div>')
    z += 1
while z < 2:
    selection_types = ["Weapon"]
    selection_slot = selection_types[0]
    selected_items = oh_selection
    selected_items_code = []
    for wep in oh_selection:
        zed = 0
        while zed < data_entrys:
            if (equipment_data['Name'].iloc[zed]) == wep:
                selected_items_code.append(equipment_data['Item Number'].iloc[zed])
            zed += 1
    for count, ele in enumerate(selected_items):
        eles = ele.find(",")
        if eles > 0:
            eles = selected_items[count]
            eles = eles.replace(",", "")
            selected_items.pop(count)
            selected_items.insert(count, eles)
    print('''<div id="''' + str(selection_slot).lower() + str(z+1) + '''_slot" class="weapon_tabcontent">''')
    print('''<div class="ohhider" id="ohhider">
    <select name="ohhiderselection" id="ohhiderselection"onchange="oh_hider()">
    <option value="All"selected="selected">All</option>
    <option value="Sword">Sword</option>
    <option value="Axe">Axe</option>
    <option value="Mace">Mace</option>
    </select>
    </div>''')
    print("<form>")
    # print("<h3>")
    # print("</h3>")
    #print('''<div style="text-align:right;float:left;width:30%;font-size:21px;">''')
    print('''<div id="wepoh"class="weaponoh_selector">''')
    t = 0
    print('''<div>
    <h3>
    <div onclick="sortbyname()"class="title_name">Name <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbydps()"class="title_num">DPS <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyphase()"class="title_phase">Phase <i class="fa fa-sort"style="font-size:15px"></i></div> 
    <div onclick="sortbyheroic()"class="title_heroic">Heroic <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyslot()"class="title_slot">Slot <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbytype()"class="title_type">Type <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbymin()"class="title_min">Min <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbymax()"class="title_max">Max <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyspeed()"class="title_speed">Speed <i class="fa fa-sort"style="font-size:15px"></i></div>
    </h3>
</div>
<br>
<hr width="90%" size="2px" color="grey" align="right"/>''')
    print('''<div class="all_sort_oh">''')
    while t < len(selected_items):
        selected_items_underscore_and_no_apo = selected_items[t]
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(" ", "_")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace("'", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(":", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(",", "")
        selected_items_df = (((equipment_data[equipment_data['Name'] == selected_items[t]])))
        selected_items_phase = (selected_items_df["Phase"]).to_string(index=False, header=False)
        selected_items_heroic = (selected_items_df["Heroic"]).to_string(index=False, header=False)
        if selected_items_heroic == "False":
            selected_items_heroic = "No"
        else:
            selected_items_heroic = "Yes"
        selected_items_slot = (selected_items_df["Slots"]).to_string(index=False, header=False)
        selected_items_slot = selected_items_slot.title()
        selected_items_type = (selected_items_df["Type"]).to_string(index=False, header=False)
        selected_items_type = selected_items_type.title()
        #selected_items_type = selected_items_type.capitalize()
        selected_items_min = (selected_items_df["Min Damage"]).to_string(index=False, header=False)
        selected_items_max = (selected_items_df["Max Damage"]).to_string(index=False, header=False)
        selected_items_speed = (selected_items_df["Speed"]).to_string(index=False, header=False)
        script_maker_names.append(selected_items[t])
        script_maker_underscored_names.append("w2_" + str(selected_items_underscore_and_no_apo))
        script_maker_function_names.append("oh")
        #<div id="w1_Angry_Dread"class="w1_Angry_Dread">
        print('''<div class="all_oh_items">''')
        print('''<div id="w2_''' + str(selected_items_underscore_and_no_apo) + '''"class="w2_''' + str(selected_items_underscore_and_no_apo) + '''">''')
        print('''<a href="javascript:void(0);" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"class="name"></a>''')
        print('''<div class="nam"hidden>''' + str(selected_items[t]) + '''</div>''')
        print('''<div class="num"></div>''')
        print('''<div class="phase">''' + str(selected_items_phase) + '''</div>''')
        print('''<div class="heroic">''' + str(selected_items_heroic) + '''</div>''')
        print('''<div class="slot">''' + str(selected_items_slot) + '''</div>''')
        print('''<div class="type">''' + str(selected_items_type) + '''</div>''')
        print('''<div class="min">''' + str(selected_items_min) + '''</div>''')
        print('''<div class="max">''' + str(selected_items_max) + '''</div>''')
        print('''<div class="speed">''' + str(selected_items_speed) + '''</div>''')
        t += 1
        print("<br>")
        print("</div>")
        
        
        print('''<hr width="90%" size="2px" color="grey" align="right"/>''')
        print("</div>")

        
    print('''</div>''')
    print('''</div>''')
    print('''<select name="''' + str(selection_slot).lower() + str(z+1) + '''" id="''' + str(selection_slot).lower() + str(z+1) + '''"''' + '''onchange="''' + str(exported_cookie_list[1]) + '''"''' + '''hidden>''')
    y = 0
    while y < len(selected_items):
        if y == 0:
            print('''    <option value="''' + str(selected_items[y]) + '''"selected="selected">''' + str(selected_items[y]) + '''</option>''')
        else:
            print('''    <option value="''' + str(selected_items[y]) + '''">''' + str(selected_items[y]) + '''</option>''')
        y += 1
    print("</select>")
    #print("</h3>")
    print("</form>")
    
    print("""<div style="text-align:center;float:center;font-size:21px;">""")
    print("<form>")
    print("Enchant:")
    print("""<select name="ohweapenchant" id="ohweapenchant" """ + '''onchange="''' + str(exported_cookie_list[cookie_enchant_loop]) + '''"''' + """>""")
    cookie_enchant_loop += 1
    print("""<option value="None"selected="selected">None</option>""")
    for enchant in enchants_weapon:
        print('''<option value="''' + str(enchant) + '''">''' + str(enchant) + '''</option>''')
    print("</select>")
    print("</form>")
    print("</div>")
    
    gem_bonus_number, cookie_socket_loop = gem_socket_bonus(gem_bonus_number, selection_slot, cookie_socket_loop)
    gemnumber, cookie_gem_loop = all_gem(gemnumber, selection_slot, cookie_gem_loop)
    
    
    print('</div>')
    z += 1
    
print("</div>")






#Equipment Starts here
equipment_data = pd.read_csv (r'EquipmentList - Gear.csv')
selection_types = ["Head","Neck","Shoulders","Back","Chest","Wrist","Gloves","Waist","Legs","Boots","Sigil"]
selection_types_len = len(selection_types)
data_entrys = len(equipment_data)
selection_slot = "Back"
square = 0
z = 0
while z < selection_types_len:
    selected_items = []
    selected_items_sc = []
    selection_slot = selection_types[z]
    x = 0
    while x < data_entrys:
        if (equipment_data['Item Slot'].iloc[x]) == selection_slot:
            selected_items.append(equipment_data['Name'].iloc[x])
        x += 1
    selected_items = sorted(selected_items)
    selected_items_code = []
    for item in selected_items:
        zed = 0
        while zed < data_entrys:
            if (equipment_data['Name'].iloc[zed]) == item:
                selected_items_code.append(equipment_data['Item Number'].iloc[zed])
            zed += 1
    for count, ele in enumerate(selected_items):
        eles = ele.find(",")
        if eles > 0:
            eles = selected_items[count]
            eles = eles.replace(",", "")
            selected_items.pop(count)
            selected_items.insert(count, eles)
    print('''<div id="''' + str(selection_slot).lower() + '''_slot" class="tabcontent">''')
    print("<form>")
    # print("<h3>")
    # print("</h3>")
    item_initals = selection_slot[:5] + selection_slot[-1:]
    print('''<div id="''' + str(item_initals) + '''"class="''' + str(item_initals) + '''_selector">''')
    t = 0
    print('''<div>
    <h3>
    <div onclick="sortbyname()"class="title_name">Name <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbydps()"class="title_num">DPS <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyphase()" class="title_phase">Phase <i class="fa fa-sort"style="font-size:15px"></i></div> 
    <div onclick="sortbyheroic()" class="title_heroic">Heroic <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbystrength()"class="title_strength">Strength <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyagility()"class="title_agility">Agility <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyap()"class="title_attackpower">Attack Power <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyhit()"class="title_hit">Hit <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbycrit()"class="title_crit">Crit <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyhaste()"class="title_haste">Haste <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyarmorpen()"class="title_armorpen">Armor Pen <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyexpertise()"class="title_expertise">Expertise <i class="fa fa-sort"style="font-size:15px"></i></div>
    </h3>
</div>
<br>
<hr width="90%" size="2px" color="grey" align="right"/>''')
    print('''<div class="all_sort_''' + str(selection_slot.lower()) + '''">''')
    while t < len(selected_items):
        selected_items_underscore_and_no_apo = selected_items[t]
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(" ", "_")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace("'", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(":", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(",", "")
        selected_items_df = (((equipment_data[equipment_data['Name'] == selected_items[t]])))
        selected_items_phase = (selected_items_df["Phase"]).to_string(index=False, header=False)
        selected_items_heroic = (selected_items_df["Heroic"]).to_string(index=False, header=False)
        if selected_items_heroic == "False":
            selected_items_heroic = "No"
        else:
            selected_items_heroic = "Yes"
        selected_items_str = (selected_items_df["Strength"]).to_string(index=False, header=False)
        selected_items_agi = (selected_items_df["Agility"]).to_string(index=False, header=False)
        selected_items_attap = (selected_items_df["Attack Power"]).to_string(index=False, header=False)
        selected_items_hit = (selected_items_df["Hit Rating"]).to_string(index=False, header=False)
        selected_items_crit = (selected_items_df["Crit Rating"]).to_string(index=False, header=False)
        selected_items_haste = (selected_items_df["Haste Rating"]).to_string(index=False, header=False)
        selected_items_armorpen = (selected_items_df["Armor Pen"]).to_string(index=False, header=False)
        selected_items_expertise = (selected_items_df["Expertise Rating"]).to_string(index=False, header=False)
        script_maker_names.append(selected_items[t])
        script_maker_underscored_names.append(str(item_initals) + "_" + str(selected_items_underscore_and_no_apo))
        script_maker_function_names.append(selection_slot)
        print('''<div class="all_''' + str(selection_slot.lower()) + '''_items">''')
        print('''<div id="''' + str(item_initals) + '''_''' + str(selected_items_underscore_and_no_apo) + '''"class="''' + str(item_initals) + '''_''' + str(selected_items_underscore_and_no_apo) + '''">''')
        print('''<a href="javascript:void(0);" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"class="name"></a>''')
        print('''<div class="nam"hidden>''' + str(selected_items[t]) + '''</div>''')
        print('''<div class="num"></div>''')
        print('''<div class="phase">''' + str(selected_items_phase) + '''</div>''')
        print('''<div class="heroic">''' + str(selected_items_heroic) + '''</div>''')
        print('''<div class="strength">''' + str(selected_items_str) + '''</div>''')
        print('''<div class="agility">''' + str(selected_items_agi) + '''</div>''')
        print('''<div class="attackpower">''' + str(selected_items_attap) + '''</div>''')
        print('''<div class="hit">''' + str(selected_items_hit) + '''</div>''')
        print('''<div class="crit">''' + str(selected_items_crit) + '''</div>''')
        print('''<div class="haste">''' + str(selected_items_haste) + '''</div>''')
        print('''<div class="armorpen">''' + str(selected_items_armorpen) + '''</div>''')
        print('''<div class="expertise">''' + str(selected_items_expertise) + '''</div>''')
        t += 1
        print("<br>")
        
        
        #TESTING THIS ONE CAT FIRST BEFORE I DO EVERYTHING
        
        print("</div>")
        
        print('''<hr width="90%" size="2px" color="grey" align="right"/>''')
        print("</div>")
        

     
    #print('''<div style="text-align:right;float:left;width:30%;font-size:21px;">''')
    # t = 0
    # # while t < len(selected_items):
    # #     print('''<a href="#" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"></a><br>''')
    # #     t += 1
    print('''</div>''')
    print('''</div>''')
    if selection_slot != "Sigil":
        print('''<select name="''' + str(selection_slot).lower() + '''" id="''' + str(selection_slot).lower() + '''"''' + '''onchange="''' + str(exported_cookie_list[cookie_gear_loop]) + '''"''' + '''hidden>''')
        cookie_gear_loop += 1
    else:
        print('''<select name="''' + str(selection_slot).lower() + '''" id="''' + str(selection_slot).lower() + '''"''' + '''onchange="''' + str(exported_cookie_list[sigil_loop]) + '''"''' + '''hidden>''')
    y = 0
    while y < len(selected_items):
        if y == 0:
            print('''    <option value="''' + str(selected_items[y]) + '''"selected="selected">''' + str(selected_items[y]) + '''</option>''')
        else:
            print('''    <option value="''' + str(selected_items[y]) + '''">''' + str(selected_items[y]) + '''</option>''')
        y += 1
    print("</select>")
    #print("</h3>")
    print("</form>")
    
    
    if selection_types[z] == enchant_types[square]:

        print("""<div style="text-align:center;float:center;font-size:21px;">""")
        print("<form>")
        print("Enchant:")
        
        print('''<select name="''' + str(enchant_types[square].lower()) + '''enchant" id="''' + str(enchant_types[square].lower()) + '''enchant"''' + '''onchange="''' + str(exported_cookie_list[cookie_enchant_loop]) + '''"''' + '''>''')
        cookie_enchant_loop += 1
        print("""<option value="None"selected="selected">None</option>""")
        if enchant_types[square] == "Head":
            enchants = enchants_head
        elif enchant_types[square] == "Shoulders":
            enchants = enchants_shoulders
        elif enchant_types[square] == "Back":
            enchants = enchants_back
        elif enchant_types[square] == "Chest":
            enchants = enchants_chest
        elif enchant_types[square] == "Wrist":
            enchants = enchants_wrist
        elif enchant_types[square] == "Gloves":
            enchants = enchants_gloves
        elif enchant_types[square] == "Legs":
            enchants = enchants_leg
        elif enchant_types[square] == "Boots":
            enchants = enchants_boots
        for enchant in enchants:
            print('''<option value="''' + str(enchant) + '''">''' + str(enchant) + '''</option>''')
        print("</select>")
        print("</form>")
        print("</div>")
        
        square += 1
    if selection_slot != "Sigil":   
        meta_gem(selection_slot)
        gem_bonus_number, cookie_socket_loop = gem_socket_bonus(gem_bonus_number, selection_slot, cookie_socket_loop)
        gemnumber, cookie_gem_loop = all_gem(gemnumber, selection_slot, cookie_gem_loop)
    
    
    
    
    
    
    print('</div>')
    z += 1
    
   
print("</div>")
print('''<div id="ring_slot" class="tabcontent">''')
print('''<div class="ring_tab">''')
print('''<button class="tablinks_ring" onclick="openRing(event, 'ring1_slot')"id="defaultOpen2">Slot1</button>''')
print('''<button class="tablinks_ring" onclick="openRing(event, 'ring2_slot')">Slot2</button>''')
print('''</div>''')


#RINGS HERE
    
z = 0
gem_bonus_number = 13
yet = 0
while z < 2:
    selection_types = ["Ring"]
    selected_items = []
    selected_items_sc = []
    selection_slot = selection_types[0]
    x = 0
    while x < data_entrys:
        if (equipment_data['Item Slot'].iloc[x]) == selection_slot:
            selected_items.append(equipment_data['Name'].iloc[x])
     #       selected_items_sc.append(equipment_data['Shortcut Name'].iloc[x])
        x += 1

    selected_items = sorted(selected_items)
    selected_items_code = []
    for item in selected_items:
        zed = 0
        while zed < data_entrys:
            if (equipment_data['Name'].iloc[zed]) == item:
                selected_items_code.append(equipment_data['Item Number'].iloc[zed])
            zed += 1
    for count, ele in enumerate(selected_items):
        eles = ele.find(",")
        if eles > 0:
            eles = selected_items[count]
            eles = eles.replace(",", "")
            selected_items.pop(count)
            selected_items.insert(count, eles)
    print('''<div id="''' + str(selection_slot).lower() + str(z+1) + '''_slot" class="ring_tabcontent">''')
    print("<form>")
    item_initals = selection_slot[:5] + selection_slot[-1:] + str(z+1)
    print('''<div id="''' + str(item_initals) + '''"class="''' + str(item_initals) + '''_selector">''')
    t = 0
    print('''<div>
    <h3>
    <div onclick="sortbyname()"class="title_name">Name <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbydps()"class="title_num">DPS <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyphase()" class="title_phase">Phase <i class="fa fa-sort"style="font-size:15px"></i></div> 
    <div onclick="sortbyheroic()" class="title_heroic">Heroic <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbystrength()"class="title_strength">Strength <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyagility()"class="title_agility">Agility <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyap()"class="title_attackpower">Attack Power <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyhit()"class="title_hit">Hit <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbycrit()"class="title_crit">Crit <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyhaste()"class="title_haste">Haste <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyarmorpen()"class="title_armorpen">Armor Pen <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyexpertise()"class="title_expertise">Expertise <i class="fa fa-sort"style="font-size:15px"></i></div>
    </h3>
</div>
<br>
<hr width="90%" size="2px" color="grey" align="right"/>''')
    print('''<div class="all_sort_ring''' + str(z+1) + '''">''')
    while t < len(selected_items):
        selected_items_underscore_and_no_apo = selected_items[t]
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(" ", "_")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace("'", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(":", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(",", "")
        selected_items_df = (((equipment_data[equipment_data['Name'] == selected_items[t]])))
        selected_items_phase = (selected_items_df["Phase"]).to_string(index=False, header=False)
        selected_items_heroic = (selected_items_df["Heroic"]).to_string(index=False, header=False)
        if selected_items_heroic == "False":
            selected_items_heroic = "No"
        else:
            selected_items_heroic = "Yes"
        selected_items_str = (selected_items_df["Strength"]).to_string(index=False, header=False)
        selected_items_agi = (selected_items_df["Agility"]).to_string(index=False, header=False)
        selected_items_attap = (selected_items_df["Attack Power"]).to_string(index=False, header=False)
        selected_items_hit = (selected_items_df["Hit Rating"]).to_string(index=False, header=False)
        selected_items_crit = (selected_items_df["Crit Rating"]).to_string(index=False, header=False)
        selected_items_haste = (selected_items_df["Haste Rating"]).to_string(index=False, header=False)
        selected_items_armorpen = (selected_items_df["Armor Pen"]).to_string(index=False, header=False)
        selected_items_expertise = (selected_items_df["Expertise Rating"]).to_string(index=False, header=False)
        script_maker_names.append(selected_items[t])
        script_maker_underscored_names.append(str(item_initals) + "_" + str(selected_items_underscore_and_no_apo))
        script_maker_function_names.append(item_initals)
        print('''<div class="all_ring''' + str(z+1) + '''_items">''')
        print('''<div id="''' + str(item_initals) + '''_''' + str(selected_items_underscore_and_no_apo) + '''"class="''' + str(item_initals) + '''_''' + str(selected_items_underscore_and_no_apo) + '''">''')
        print('''<a href="javascript:void(0);" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"class="name"></a>''')
        print('''<div class="nam"hidden>''' + str(selected_items[t]) + '''</div>''')
        print('''<div class="num"></div>''')
        print('''<div class="phase">''' + str(selected_items_phase) + '''</div>''')
        print('''<div class="heroic">''' + str(selected_items_heroic) + '''</div>''')
        print('''<div class="strength">''' + str(selected_items_str) + '''</div>''')
        print('''<div class="agility">''' + str(selected_items_agi) + '''</div>''')
        print('''<div class="attackpower">''' + str(selected_items_attap) + '''</div>''')
        print('''<div class="hit">''' + str(selected_items_hit) + '''</div>''')
        print('''<div class="crit">''' + str(selected_items_crit) + '''</div>''')
        print('''<div class="haste">''' + str(selected_items_haste) + '''</div>''')
        print('''<div class="armorpen">''' + str(selected_items_armorpen) + '''</div>''')
        print('''<div class="expertise">''' + str(selected_items_expertise) + '''</div>''')
        t += 1
        print("<br>")
        print("</div>")
        print('''<hr width="90%" size="2px" color="grey" align="right"/>''')
        print("</div>")

    # print("<h3>")
    # print('''<div style="text-align:right;float:left;width:30%;font-size:21px;">''')
    # t = 0
    # while t < len(selected_items):
    #     print('''<a href="#" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"></a><br>''')
    #     t += 1
    print('''</div>''')
    print('''</div>''')
    print('''<select name="''' + str(selection_slot).lower() + str(z+1) + '''" id="''' + str(selection_slot).lower() + str(z+1) + '''"''' + '''onchange="''' + str(exported_cookie_list[cookie_gear_loop]) + '''"''' + '''hidden>''')
    cookie_gear_loop += 1
    y = 0
    while y < len(selected_items):
        if y == 0:
            print('''    <option value="''' + str(selected_items[y]) + '''"selected="selected">''' + str(selected_items[y]) + '''</option>''')
        else:
            print('''    <option value="''' + str(selected_items[y]) + '''">''' + str(selected_items[y]) + '''</option>''')
        y += 1
    #print("</ul>")
    print("</select>")
    print("</h3>")
    print("</form>")
    
    
    print("""<div style="text-align:center;float:center;font-size:21px;">""")
    print("<form>")
    print("Enchant:")
    print('''<select name="ring''' + str(yet+1) + '''enchant" id="ring''' + str(yet+1) + """enchant" """ + '''onchange="''' + str(exported_cookie_list[cookie_enchant_loop]) + '''"''' + """>""")
    cookie_enchant_loop += 1
    print("""<option value="None"selected="selected">None</option>""")
    for enchant in enchants_rings:
        print('''<option value="''' + str(enchant) + '''">''' + str(enchant) + '''</option>''')
    print("</select>")
    print("</form>")
    print("</div>")
    yet += 1
    
    gem_bonus_number, cookie_socket_loop = gem_socket_bonus(gem_bonus_number, selection_slot, cookie_socket_loop)
    gemnumber, cookie_gem_loop = all_gem(gemnumber, selection_slot, cookie_gem_loop)
    
    
    print('</div>')
    z += 1
print("</div>")






print('''<div id="trinket_slot" class="tabcontent">''')
print('''<div class="trinket_tab">''')
print('''<button class="tablinks_trinket" onclick="openTrinket(event, 'trinket1_slot')"id="defaultOpen1">Slot1</button>''')
print('''<button class="tablinks_trinket" onclick="openTrinket(event, 'trinket2_slot')">Slot2</button>''')
print('''</div>''')


    
z = 0
while z < 2:
    selection_types = ["Trinket"]
    selected_items = []
    selected_items_sc = []
    selection_slot = selection_types[0]
    x = 0
    while x < data_entrys:
        if (equipment_data['Item Slot'].iloc[x]) == selection_slot:
            selected_items.append(equipment_data['Name'].iloc[x])
        x += 1

    selected_items = sorted(selected_items)
    selected_items_code = []
    for item in selected_items:
        zed = 0
        while zed < data_entrys:
            if (equipment_data['Name'].iloc[zed]) == item:
                selected_items_code.append(equipment_data['Item Number'].iloc[zed])
            zed += 1
    for count, ele in enumerate(selected_items):
        eles = ele.find(",")
        if eles > 0:
            eles = selected_items[count]
            eles = eles.replace(",", "")
            selected_items.pop(count)
            selected_items.insert(count, eles)
    print('''<div id="''' + str(selection_slot).lower() + str(z+1) + '''_slot" class="trinket_tabcontent">''')
    print("<form>")
    item_initals = selection_slot[:5] + selection_slot[-1:] + str(z+1)
    print('''<div id="''' + str(item_initals) + '''"class="''' + str(item_initals) + '''_selector">''')
    t = 0
    print('''<div>
    <h3>
    <div onclick="sortbyname()"class="title_name">Name <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbydps()"class="title_num">DPS <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyphase()" class="title_phase">Phase <i class="fa fa-sort"style="font-size:15px"></i></div> 
    <div onclick="sortbyheroic()" class="title_heroic">Heroic <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbystrength()"class="title_strength">Strength <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyagility()"class="title_agility">Agility <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyap()"class="title_attackpower">Attack Power <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyhit()"class="title_hit">Hit <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbycrit()"class="title_crit">Crit <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyhaste()"class="title_haste">Haste <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyarmorpen()"class="title_armorpen">Armor Pen <i class="fa fa-sort"style="font-size:15px"></i></div>
    <div onclick="sortbyexpertise()"class="title_expertise">Expertise <i class="fa fa-sort"style="font-size:15px"></i></div>
    </h3>
</div>
<br>
<hr width="90%" size="2px" color="grey" align="right"/>''')
    print('''<div class="all_sort_trinket''' + str(z+1) + '''">''')
    while t < len(selected_items):
        selected_items_underscore_and_no_apo = selected_items[t]
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(" ", "_")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace("'", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(":", "")
        selected_items_underscore_and_no_apo = selected_items_underscore_and_no_apo.replace(",", "")
        selected_items_df = (((equipment_data[equipment_data['Name'] == selected_items[t]])))
        selected_items_phase = (selected_items_df["Phase"]).to_string(index=False, header=False)
        selected_items_heroic = (selected_items_df["Heroic"]).to_string(index=False, header=False)
        if selected_items_heroic == "False":
            selected_items_heroic = "No"
        else:
            selected_items_heroic = "Yes"
        selected_items_str = (selected_items_df["Strength"]).to_string(index=False, header=False)
        selected_items_agi = (selected_items_df["Agility"]).to_string(index=False, header=False)
        selected_items_attap = (selected_items_df["Attack Power"]).to_string(index=False, header=False)
        selected_items_hit = (selected_items_df["Hit Rating"]).to_string(index=False, header=False)
        selected_items_crit = (selected_items_df["Crit Rating"]).to_string(index=False, header=False)
        selected_items_haste = (selected_items_df["Haste Rating"]).to_string(index=False, header=False)
        selected_items_armorpen = (selected_items_df["Armor Pen"]).to_string(index=False, header=False)
        selected_items_expertise = (selected_items_df["Expertise Rating"]).to_string(index=False, header=False)
        script_maker_names.append(selected_items[t])
        script_maker_underscored_names.append(str(item_initals) + "_" + str(selected_items_underscore_and_no_apo))
        script_maker_function_names.append(item_initals)
        print('''<div class="all_trinket''' + str(z+1) + '''_items">''')
        print('''<div id="''' + str(item_initals) + '''_''' + str(selected_items_underscore_and_no_apo) + '''"class="''' + str(item_initals) + '''_''' + str(selected_items_underscore_and_no_apo) + '''">''')
        print('''<a href="javascript:void(0);" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"class="name"></a>''')
        print('''<div class="nam"hidden>''' + str(selected_items[t]) + '''</div>''')
        print('''<div class="num"></div>''')
        print('''<div class="phase">''' + str(selected_items_phase) + '''</div>''')
        print('''<div class="heroic">''' + str(selected_items_heroic) + '''</div>''')
        print('''<div class="strength">''' + str(selected_items_str) + '''</div>''')
        print('''<div class="agility">''' + str(selected_items_agi) + '''</div>''')
        print('''<div class="attackpower">''' + str(selected_items_attap) + '''</div>''')
        print('''<div class="hit">''' + str(selected_items_hit) + '''</div>''')
        print('''<div class="crit">''' + str(selected_items_crit) + '''</div>''')
        print('''<div class="haste">''' + str(selected_items_haste) + '''</div>''')
        print('''<div class="armorpen">''' + str(selected_items_armorpen) + '''</div>''')
        print('''<div class="expertise">''' + str(selected_items_expertise) + '''</div>''')
        t += 1
        print("<br>")
        print("</div>")
        print('''<hr width="90%" size="2px" color="grey" align="right"/>''')
        print("</div>")

    # print("<h3>")
    # print('''<div style="text-align:right;float:left;width:30%;font-size:21px;">''')
    # t = 0
    # while t < len(selected_items):
    #     print('''<a href="#" data-wowhead="item=''' + str(selected_items_code[t]) + '''&domain=wrath"></a><br>''')
    #     t += 1
    print('''</div>''')
    print('''</div>''')
    print('''<select name="''' + str(selection_slot).lower() + str(z+1) + '''" id="''' + str(selection_slot).lower() + str(z+1) + '''"''' + '''onchange="''' + str(exported_cookie_list[cookie_gear_loop]) + '''"''' + '''hidden>''')
    cookie_gear_loop += 1
    y = 0
    while y < len(selected_items):
        if y == 0:
            print('''    <option value="''' + str(selected_items[y]) + '''"selected="selected">''' + str(selected_items[y]) + '''</option>''')
        else:
            print('''    <option value="''' + str(selected_items[y]) + '''">''' + str(selected_items[y]) + '''</option>''')
        y += 1
    print("</select>")
    print("</h3>")
    print("</form>")
    gem_bonus_number, cookie_socket_loop = gem_socket_bonus(gem_bonus_number, selection_slot, cookie_socket_loop)
    gemnumber, cookie_gem_loop = all_gem(gemnumber, selection_slot, cookie_gem_loop)
    print('</div>')
    z += 1

print("</div>")

print("<div>")
print("<script>")
script_num = 0
script_maker_functions = []
for i in script_maker_function_names:
    if i == "Back":
        fun = "select_back"
    elif i == "Boots":
        fun = "select_boots"
    elif i == "Chest":
        fun = "select_chest"
    elif i == "Gloves":
        fun = "select_gloves"
    elif i == "Head":
        fun = "select_head"
    elif i == "Legs":
        fun = "select_legs"
    elif i == "Neck":
        fun = "select_neck"
    elif i == "Ringg1":
        fun = "select_ring1"
    elif i == "Ringg2":
        fun = "select_ring2"
    elif i == "Shoulders":
        fun = "select_shoulders"
    elif i == "Sigil":
        fun = "select_sigil"
    elif i == "Trinkt1":
        fun = "select_trinket1"
    elif i == "Trinkt2":
        fun = "select_trinket2"
    elif i == "Waist":
        fun = "select_waist"
    elif i == "Wrist":
        fun = "select_wrist"
    elif i == "mh":
        fun = "select_wep"
    elif i == "oh":
        fun = "select_wep2"
    script_maker_functions.append(fun)
for script_names in script_maker_names:
    print('''document.querySelector(".''' + str(script_maker_underscored_names[script_num]) + '''").addEventListener('click', function(){''' + str(script_maker_functions[script_num]) + '''("''' + str(script_names) + '''")}, false);''')
    script_num += 1


#so need the variable for full name of every item, and the .w1_name for every item
#script_maker_names
#script_maker_underscored_names
#script_maker_function_names


#document.querySelector(".w1_Avools_Sword_of_Jin").addEventListener('click', function(){select_wep("Avool's Sword of Jin")}, false);

print("</script>")
print("</div>")
print('''
<div id="thankyou" class="thankyou">
<div style="text-align: center; font-size: 10px"><h3>
    <br>
    <br>
    Github availabe @ https://github.com/Krught/dksim
    <br>
    <br>
    Please report any bugs, or request any new features
    <br>
    <br>
    - Remour (Benediction)
    
</h3>
</div>
</div>''')
# Out:
# <div id="weapon_slot" class="tabcontent">
# <div class="weapon_tab">
# <button class="tablinks_weapon" onclick="openWeapon(event, 'weapon1_slot')"id="defaultOpen3">Main Hand</button>
# <button class="tablinks_weapon" onclick="openWeapon(event, 'weapon2_slot')">Off Hand</button>
# </div>
# <div id="weapon1_slot" class="weapon_tabcontent">
# <div class="mhhider" id = "mhhider">
#     <select name="mhhiderselection" id="mhhiderselection"onchange="mh_hider()">
#     <option value="All"selected="selected">All</option>
#     <option value="Sword">Sword</option>
#     <option value="Axe">Axe</option>
#     <option value="Mace">Mace</option>
#     <option value="Polearm">Polearm</option>
#     </select>
#     <select name="mh2hselection" id="mh2hselection"onchange="mh_2h()">
#     <option value="All"selected="selected">All</option>
#     <option value="2hand">2-Hand</option>
#     <option value="1hand">1-Hand</option>
#     </select>
#     </div>
# <form>
# ...
